# %%
import pandas as pd
from techminer.io import load_file


# !rm -rf datastore/datastore.csv

scopus_df = load_file(filepath="techminer/tests/data/scopus.csv", filetype="scopus", datastorepath="./datastore")
wos_df = load_file(filepath="techminer/tests/data/savedrecs.txt", filetype="wos", datastorepath="./datastore")
dim_df = load_file(filepath="techminer/tests/data/dimensions.csv", filetype="dimensions", datastorepath="./datastore")

display(
    scopus_df.head(),
    wos_df.head(),
    dim_df.head(),
)
# Out:
# WARNING - Duplicate rows found in ./datastore/datastore.csv - Records saved to ./datastore/duplicates.csv
# WARNING - Duplicate rows found in ./datastore/datastore.csv - Records saved to ./datastore/duplicates.csv
# WARNING - Duplicate rows found in ./datastore/datastore.csv - Records saved to ./datastore/duplicates.csv
#                                              authors  \
# 0                    Al-Khowarizmi A;Syah R;Elveny M
# 1           Chaudhry SM;Ahmed R;Huynh TLD;Benjasak C
# 2  Felipe IJDS;Mendes-Da-Silva W;Leal CC;Braun Sa...
# 3       Narayanaswamy T;Karthika P;Balasubramanian K
# 4                      Zheng KW;Cheong JH;Jafarian M
#
#                                       document_title  pub_year  \
# 0  The Model of Business Intelligence Development...      2022
# 1  Tail risk and systemic risk of finance and tec...      2022
# 2  Reward crowdfunding campaigns: Time-to-success...      2022
# 3  Blockchain Enterprise: Use Cases on Multiple I...      2022
# 4  Intention to Adopt Robo-Advisors Among Malaysi...      2022
#
#                                     publication_name  \
# 0              LECTURE NOTES IN NETWORKS AND SYSTEMS
# 1        TECHNOLOGICAL FORECASTING AND SOCIAL CHANGE
# 2                       JOURNAL OF BUSINESS RESEARCH
# 3  EAISPRINGER INNOVATIONS IN COMMUNICATION AND C...
# 4              LECTURE NOTES IN NETWORKS AND SYSTEMS
#
#                               doi      issn           isbn  pubmed_id
# 0    10.1007/978-981-16-2377-6_13  23673370  9789811623769        NaN
# 1  10.1016/J.TECHFORE.2021.121191  00401625            NaN        NaN
# 2   10.1016/J.JBUSRES.2021.09.004  01482963            NaN        NaN
# 3     10.1007/978-3-030-76216-2_8  25228595            NaN        NaN
# 4    10.1007/978-3-030-82616-1_54  23673370  9783030826154        NaN
#                    authors                    document_title  \
# 0              Puschmann T                           Fintech
# 1              [Anonymous]                           FINTECH
# 2               Magnuson W                Regulating Fintech
# 3  Gazel M;Schwienbacher A  Entrepreneurial fintech clusters
# 4                 Gandel S          CITIGROUP DOES 'FINTECH'
#
#                             publication_name      issn pub_year  \
# 0  BUSINESS  INFORMATION SYSTEMS ENGINEERING  18670202     2017
# 1                                    FORTUNE  00158259     2017
# 2                      VANDERBILT LAW REVIEW  00422533     2018
# 3                   SMALL BUSINESS ECONOMICS  0921898X     2021
# 4                                    FORTUNE  00158259     2016
#
#                           doi     eissn pubmed_id
# 0   10.1007/S12599-017-0464-6       NaN       NaN
# 1                         NaN  2169155X       NaN
# 2                         NaN  19429886       NaN
# 3  10.1007/S11187-020-00331-1  15730913       NaN
# 4                         NaN  2169155X       NaN
#                              doi  \
# 0         10.3390/IJERPH16224340
# 1  10.1016/J.HELIYON.2021.E06782
# 2              10.1063/5.0004487
# 3  10.1016/J.HELIYON.2021.E07821
# 4              10.3390/S21051594
#
#                                       document_title  \
# 0  Can FinTech Development Curb Agricultural Nonp...
# 1  Detection of fintech P2P lending issues in Ind...
# 2  Dynamics of fintech terms in news and blogs an...
# 3  Examining factors that boost intention and loy...
# 4  Follow the Trail: Machine Learning for Fraud D...
#
#                                     publication_name  pub_year  \
# 0  INTERNATIONAL JOURNAL OF ENVIRONMENTAL RESEARC...      2019
# 1                                            HELIYON      2021
# 2  CHAOS AN INTERDISCIPLINARY JOURNAL OF NONLINEA...      2020
# 3                                            HELIYON      2021
# 4                                            SENSORS      2021
#
#                                              authors
# 0                        Jiang S;Qiu S;Zhou H;Chen M
# 1                      Suryono R;Budi R;Purwandari I
# 2                                Ciulla F;Mantegna R
# 3                                               Le M
# 4  Stojanović B;Božić J;Hofer-Schmitz K;Nahrgang ...

# %%
datastore = pd.read_csv("datastore/datastore.csv")

doi = datastore.doi.duplicated(keep=False) & ~datastore.doi.isna()
print(doi.sum())


display(
    datastore[doi].sort_values(by=["doi"]).head(15),
    datastore[doi].sort_values(by=["doi"]).tail(15),
)

# %%
datastore = pd.read_csv("datastore/datastore.csv")

document_title = datastore.document_title.duplicated(keep=False) & ~datastore.document_title.isna()
print(document_title.sum())


display(
    datastore[document_title].sort_values(by=["document_title"]).head(25),
    datastore[document_title].sort_values(by=["document_title"]).tail(25),
)

# %%
datastore = pd.read_csv("datastore/datastore.csv")

display(
    datastore.sort_values(by=["document_title"]).head(15),
    datastore.sort_values(by=["document_title"]).tail(15),
)

# %%
datastore.doi.isna().sum()

# %%
datastore.doi.drop_duplicates().shape[0]

# %%
datastore.shape

# %%
253+4544

# %%
datastore.doi.isna().sum()

# %%
import logging

logging.basicConfig(format='%(levelname)s - %(message)s', level=logging.DEBUG)
logging.debug('This message should appear on the console')
logging.info('So should this')
logging.warning('And this, too')
